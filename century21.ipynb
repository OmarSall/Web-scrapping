# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")

c = r.content

# c

soup = BeautifulSoup(c,"html.parser")

# print(soup.prettify())

all = soup.find_all("div", {"class": "propertyRow"})

# all

# len(all)

# all[0].find_all("h4", {"class": "propPrice"})

all[0].find("h4", {"class": "propPrice"}).text.replace("\n","").replace(" ", "")

page_nr = soup.find_all("a", {"class": "Page"})[-1].text
# print(page_nr)

# %%
# c
# Out:
# b'<!DOCTYPE html>\n<!-- saved from url=(0111)http://web.archive.org/web/20130107060952/http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/ -->\n<html lang="en" style="margin: 0px;overflow:hidden"><script async="" src="./LCWYROCKSPRINGS2_files/beacon.js"></script><script type="text/javascript" async="" src="./LCWYROCKSPRINGS2_files/ga.js"></script><script src="chrome-extension://pkljnnogdmlajgaoodihioopfdkpgjgg/Kernel.js?0.7820731684147217"></script><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n\n\n<script type="text/javascript" src="./LCWYROCKSPRINGS2_files/analytics.js"></script>\n<script type="text/javascript">archive_analytics.values.server_name="wwwb-app0.us.archive.org";archive_analytics.values.server_ms=460;</script>\n<link type="text/css" rel="stylesheet" href="./LCWYROCKSPRINGS2_files/banner-styles.css">\n\n\n      <title>Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, AZ</title>\n\n      <meta name="title" content="Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, AZ">\n      <meta name="keywords" content="Rock Springs real estate, Rock Springs homes, Rock Springs homes for sale, Rock Springs properties, Rock Springs listings, Rock Springs houses for sale, AZ real estate, AZ homes, AZ homes for sale, AZ properties, AZ listings, AZ houses for sale">\n      <meta name="description" content="Search Rock Springs real estate property listings to find homes for sale in Rock Springs, AZ. Browse houses for sale in Rock Springs today!">\n      <meta http-equiv="X-UA-Compatible" content="IE=8, IE=9">\n\n\n         <link rel="stylesheet" type="text/css" href="./LCWYROCKSPRINGS2_files/defaultLiquidMapCSS.css">\n\n         <link rel="stylesheet" type="text/css" href="./LCWYROCKSPRINGS2_files/liquidmapping.css">\n\n      <script>\n         (function(){document.domain=function(){var a=document.location.host.split(".");return a[a.length-2]+".com"}()})();\n      </script><script src="chrome-extension://pkljnnogdmlajgaoodihioopfdkpgjgg/files/foreground.js?0.7087595272600125"></script>\n\n         <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/defaultJS.js"></script>\n\n         <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/la.js"></script>\n\n         <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/raphael.js"></script>\n\n         <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/ImageCache.js"></script>\n\n         <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/mapcontrol.ashx"></script><script src="./LCWYROCKSPRINGS2_files/veapicore.js" type="text/javascript"></script>\n\n         <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/LIQMAPPING_ONLY_JS.js"></script><style>.VE_Pushpin_Popup{position: absolute; z-index: 1000; display: none;}</style>\n\n         <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/moreSearchOptions.js"></script>\n\n         <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/surroundingAreasMapping.js"></script>\n\n         <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/surroundingAreasMappingDefault.js"></script>\n\n         <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/dynamic.js"></script>\n\n\n         <link rel="canonical" href="http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/">\n\n\n      <script language="JavaScript">\n         myc21.setFacebookAppId(\'113564428714357\');\n      </script>\n      <!--[if lte IE 8]>\n         <link rel="stylesheet" type="text/css" href="/css/ie8fix.css" />\n      <![endif]-->\n      <!--[if lte IE 7]>\n         <link rel="stylesheet" type="text/css" href="/css/ie7fix.css" />\n      <![endif]-->\n      <!--[if IE 6]>\n         <script src="/js/ie6pngfix.js"></script>\n      <![endif]-->\n\n\n         <script type="text/javascript">\n            var _gaq = _gaq || [];\n\n//            _gaq.push([\'listhub._setAccount\', \'UA-7095058-1\' ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0111)http://web.archive.org/web/20130107060952/http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/ -->
# <html lang="en" style="margin: 0px;overflow:hidden">
#  <script async="" src="./LCWYROCKSPRINGS2_files/beacon.js">
#  </script>
#  <script async="" src="./LCWYROCKSPRINGS2_files/ga.js" type="text/javascript">
#  </script>
#  <script src="chrome-extension://pkljnnogdmlajgaoodihioopfdkpgjgg/Kernel.js?0.7820731684147217">
#  </script>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script src="./LCWYROCKSPRINGS2_files/analytics.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    archive_analytics.values.server_name="wwwb-app0.us.archive.org";archive_analytics.values.server_ms=460;
#   </script>
#   <link href="./LCWYROCKSPRINGS2_files/banner-styles.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, AZ
#   </title>
#   <meta content="Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, AZ" name="title"/>
#   <meta content="Rock Springs real estate, Rock Springs homes, Rock Springs homes for sale, Rock Springs properties, Rock Springs listings, Rock Springs houses for sale, AZ real estate, AZ homes, AZ homes for sale, AZ properties, AZ listings, AZ houses for sale" name="keywords"/>
#   <meta content="Search Rock Springs real estate property listings to find homes for sale in Rock Springs, AZ. Browse houses for sale in Rock Springs today!" name="description"/>
#   <meta content="IE=8, IE=9" http-equiv="X-UA-Compatible"/>
#   <link href="./LCWYROCKSPRINGS2_files/defaultLiquidMapCSS.css" rel="stylesheet" type="text/css"/>
#   <link href="./LCWYROCKSPRINGS2_files/liquidmapping.css" rel="stylesheet" type="text/css"/>
#   <script>
#    (function(){document.domain=function(){var a=document.location.host.split(".");return a[a.length-2]+".com"}()})();
#   </script>
#   <script src="chrome-extension://pkljnnogdmlajgaoodihioopfdkpgjgg/files/foreground.js?0.7087595272600125">
#   </script>
#   <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/defaultJS.js">
#   </script>
#   <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/la.js">
#   </script>
#   <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/raphael.js">
#   </script>
#   <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/ImageCache.js">
#   </script>
#   <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/mapcontrol.ashx">
#   </script>
#   <script src="./LCWYROCKSPRINGS2_files/veapicore.js" type="text/javascript">
#   </script>
#   <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/LIQMAPPING_ONLY_JS.js">
#   </script>
#   <style>
#    .VE_Pushpin_Popup{position: absolute; z-index: 1000; display: none;}
#   </style>
#   <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/moreSearchOptions.js">
#   </script>
#   <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/surroundingAreasMapping.js">
#   </script>
#   <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/surroundingAreasMappingDefault.js">
#   </script>
#   <script language="JavaScript" src="./LCWYROCKSPRINGS2_files/dynamic.js">
#   </script>
#   <link href="http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/" rel="canonical"/>
#   <script language="JavaScript">
#    myc21.setFacebookAppId('113564428714357');
#   </script>
#   <!--[if lte IE 8]>
#          <link rel="stylesheet" type="text/css" href="/css/ie8fix.css" />
#       <![endif]-->
#   <!--[if lte IE 7]>
#          <link rel="stylesheet" type="text/css" href="/css/ie7fix.css" />
#       <![endif]-->
#   <!--[if IE 6]>
#          <script src="/js/ie6pngfix.js"></script>
#       <![endif]-->
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#
# //            _gaq.push(['listhub._setAccount', 'UA-7095058-1']);
# //            _gaq.push(['listhub._setLocalRemoteServerMode']);
# //            _gaq.push(['listhub._setLocalGifPath', ('https:' == document.location.protocol ? 'https:' : 'http:' ) + '//tracking.listhub.net/images/event.gif'] );
#
#             _gaq.push(['_setAccount', 'UA-7095058-1']);
#             _gaq.push(['_setDomainName', '.century21.com']);
#             _gaq.push(['_trackPageview']);
#
#             (function() {
#                var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#                ga.src = ('https:' == document.location.protocol ? '/web/20130107060952/https://ssl' : '/web/20130107060952/http://www') + '.google-analytics.com/ga.js';
#                var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#             })();
#   </script>
#   <script src="./LCWYROCKSPRINGS2_files/veapiOverlayStyleV2.js" type="text/javascript">
#   </script>
#   <link href="./LCWYROCKSPRINGS2_files/veapiOverlayStyleV2.css" rel="stylesheet" rev="stylesheet" type="text/css"/>
#   <style id="style-1-cropbar-clipper">
#    /* Copyright 2014 Evernote Corporation. All rights reserved. */
# .en-markup-crop-options {
#     top: 18px !important;
#     left: 50% !important;
#     margin-left: -100px !important;
#     width: 200px !important;
#     border: 2px rgba(255,255,255,.38) solid !important;
#     border-radius: 4px !important;
# }
#
# .en-markup-crop-options div div:first-of-type {
#     margin-left: 0px !important;
# }
#   </style>
#  </head>
#  <body class="liquidLayout" id="results">
#   <div class="" id="wm-ipp" lang="en" style="display: block;">
#    <div style="position:fixed;left:0;top:0;width:100%!important">
#     <div id="wm-ipp-inside">
#      <table style="width:100%;">
#       <tbody>
#        <tr>
#         <td id="wm-logo">
#          <a href="http://web.archive.org/web/" title="Wayback Machine home page">
#           <img alt="Wayback Machine" border="0" height="39" src="./LCWYROCKSPRINGS2_files/wayback-toolbar-logo.png" width="110"/>
#          </a>
#         </td>
#         <td class="c">
#          <table style="margin:0 auto;">
#           <tbody>
#            <tr>
#             <td class="u" colspan="2">
#              <form action="http://web.archive.org/web/form-submit.jsp" id="wmtb" method="get" name="wmtb" target="_top">
#               <input id="wmtbURL" name="url" onfocus="this.focus();this.select();" style="width:400px;" type="text" value="http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/"/>
#               <input name="type" type="hidden" value="replay"/>
#               <input name="date" type="hidden" value="20130107060952"/>
#               <input type="submit" value="Go"/>
#               <span id="wm_tb_options" style="display:block;">
#               </span>
#              </form>
#             </td>
#             <td class="n" rowspan="2">
#              <table>
#               <tbody>
#                <!-- NEXT/PREV MONTH NAV AND MONTH INDICATOR -->
#                <tr class="m">
#                 <td class="b" nowrap="nowrap">
#                  <a href="http://web.archive.org/web/20111119163440/http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/" title="19 Nov 2011">
#                   NOV
#                  </a>
#                 </td>
#                 <td class="c" id="displayMonthEl" title="You are here: 6:09:52 Jan 7, 2013">
#                  Jan
#                 </td>
#                 <td class="f" nowrap="nowrap">
#                  Feb
#                 </td>
#                </tr>
#                <!-- NEXT/PREV CAPTURE NAV AND DAY OF MONTH INDICATOR -->
#                <tr class="d">
#                 <td class="b" nowrap="nowrap">
#                  <a href="http://web.archive.org/web/20111119163440/http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/" title="16:34:40 Nov 19, 2011">
#                   <img alt="Previous capture" border="0" height="16" src="./LCWYROCKSPRINGS2_files/wm_tb_prv_on.png" width="14"/>
#                  </a>
#                 </td>
#                 <td class="c" id="displayDayEl" style="width:34px;font-size:24px;" title="You are here: 6:09:52 Jan 7, 2013">
#                  7
#                 </td>
#                 <td class="f" nowrap="nowrap">
#                  <img alt="Next capture" border="0" height="16" src="./LCWYROCKSPRINGS2_files/wm_tb_nxt_off.png" width="14"/>
#                 </td>
#                </tr>
#                <!-- NEXT/PREV YEAR NAV AND YEAR INDICATOR -->
#                <tr class="y">
#                 <td class="b" nowrap="nowrap">
#                  <a href="http://web.archive.org/web/20111119163440/http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/" title="19 Nov 2011">
#                   <strong>
#                    2011
#                   </strong>
#                  </a>
#                 </td>
#                 <td class="c" id="displayYearEl" title="You are here: 6:09:52 Jan 7, 2013">
#                  2013
#                 </td>
#                 <td class="f" nowrap="nowrap">
#                  2014
#                 </td>
#                </tr>
#               </tbody>
#              </table>
#             </td>
#            </tr>
#            <tr>
#             <td class="s">
#              <a class="t" href="http://web.archive.org/web/20130107060952*/http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/" title="See a list of every capture for this URL">
#               2 captures
#              </a>
#              <div class="r" title="Timespan for captures of this URL">
#               19 Nov 11 - 7 Jan 13
#              </div>
#             </td>
#             <td class="k">
#              <a href="http://web.archive.org/web/20090801000000/http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/" id="wm-graph-anchor">
#               <div id="wm-ipp-sparkline" title="Explore captures for this URL">
#                <img alt="sparklines" border="0" height="27" id="sparklineImgId" onmousemove="__wm.mv(event,this)" onmouseout="__wm.st(0)" onmouseover="__wm.st(1)" src="./LCWYROCKSPRINGS2_files/graph.jsp" width="525"/>
#                <div class="yt" style="display: none; width: 25px; height: 27px; left: 325px;">
#                </div>
#                <div class="mt" style="display: none; width: 2px; height: 27px; left: 340px;">
#                </div>
#               </div>
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </td>
#         <td class="r">
#          <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/#close" onclick="__wm.h();return false;" style="background-image:url(/static/images/toolbar/wm_tb_close.png);top:5px;" title="Close the toolbar">
#           Close
#          </a>
#          <a href="http://faq.web.archive.org/" style="background-image:url(/static/images/toolbar/wm_tb_help.png);bottom:5px;" target="_BLANK" title="You have selected a link to a website that is not owned or maintained by Century21.com.  Different terms of use and privacy policies will apply. Get some help using the Wayback Machine">
#           Help
#          </a>
#         </td>
#        </tr>
#       </tbody>
#      </table>
#     </div>
#    </div>
#   </div>
#   <!-- BEGIN WAYBACK TOOLBAR INSERT -->
#   <script src="./LCWYROCKSPRINGS2_files/disclaim-element.js" type="text/javascript">
#   </script>
#   <script src="./LCWYROCKSPRINGS2_files/graph-calc.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
# var __wm = (function(imgWidth,imgHeight,yearImgWidth,monthImgWidth){
# var wbPrefix = "/web/";
# var wbCurrentUrl = "http://www.century21.com/real-estate/rock-springs-az/LCAZROCKSPRINGS/";
#
# var firstYear = 1996;
# var displayDay = "7";
# var displayMonth = "Jan";
# var displayYear = "2013";
# var prettyMonths = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"];
# var $D=document,$=function(n){return document.getElementById(n)};
# var trackerVal,curYear = -1,curMonth = -1;
# var yearTracker,monthTracker;
# function showTrackers(val) {
#   if (val===trackerVal) return;
#   var $ipp=$("wm-ipp");
#   var $y=$("displayYearEl"),$m=$("displayMonthEl"),$d=$("displayDayEl");
#   if (val) {
#     $ipp.className="hi";
#   } else {
#     $ipp.className="";
#     $y.innerHTML=displayYear;$m.innerHTML=displayMonth;$d.innerHTML=displayDay;
#   }
#   yearTracker.style.display=val?"inline":"none";
#   monthTracker.style.display=val?"inline":"none";
#   trackerVal = val;
# }
# function trackMouseMove(event,element) {
#   var eventX = getEventX(event);
#   var elementX = getElementX(element);
#   var xOff = Math.min(Math.max(0, eventX - elementX),imgWidth);
#   var monthOff = xOff % yearImgWidth;
#
#   var year = Math.floor(xOff / yearImgWidth);
#   var monthOfYear = Math.min(11,Math.floor(monthOff / monthImgWidth));
#   // 1 extra border pixel at the left edge of the year:
#   var month = (year * 12) + monthOfYear;
#   var day = monthOff % 2==1?15:1;
#   var dateString = zeroPad(year + firstYear) + zeroPad(monthOfYear+1,2) +
#     zeroPad(day,2) + "000000";
#
#   $("displayYearEl").innerHTML=year+firstYear;
#   $("displayMonthEl").innerHTML=prettyMonths[monthOfYear];
#   // looks too jarring when it changes..
#   //$("displayDayEl").innerHTML=zeroPad(day,2);
#   var url = wbPrefix + dateString + '/' +  wbCurrentUrl;
#   $("wm-graph-anchor").href=url;
#
#   if(curYear != year) {
#     var yrOff = year * yearImgWidth;
#     yearTracker.style.left = yrOff + "px";
#     curYear = year;
#   }
#   if(curMonth != month) {
#     var mtOff = year + (month * monthImgWidth) + 1;
#     monthTracker.style.left = mtOff + "px";
#     curMonth = month;
#   }
# }
# function hideToolbar() {
#   $("wm-ipp").style.display="none";
# }
# function bootstrap() {
#   var $spk=$("wm-ipp-sparkline");
#   yearTracker=$D.createElement('div');
#   yearTracker.className='yt';
#   with(yearTracker.style){
#     display='none';width=yearImgWidth+"px";height=imgHeight+"px";
#   }
#   monthTracker=$D.createElement('div');
#   monthTracker.className='mt';
#   with(monthTracker.style){
#     display='none';width=monthImgWidth+"px";height=imgHeight+"px";
#   }
#   $spk.appendChild(yearTracker);
#   $spk.appendChild(monthTracker);
#
#   var $ipp=$("wm-ipp");
#   $ipp&&disclaimElement($ipp);
# }
# return{st:showTrackers,mv:trackMouseMove,h:hideToolbar,bt:bootstrap};
# })(525, 27, 25, 2);//]]>
#   </script>
#   <style type="text/css">
#    body {
#   margin-top:0 !important;
#   padding-top:0 !important;
#   min-width:800px !important;
# }
#   </style>
#   <script type="text/javascript">
#    __wm.bt();
#   </script>
#   <!-- END WAYBACK TOOLBAR INSERT -->
#   <script>
#    var _comscore = _comscore || [];
#          _comscore.push({ c1: "2", c2: "7705242" });
#          (function() {
#             var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#             s.src = (document.location.protocol == "https:" ? "/web/20130107060952/https://sb" : "/web/20130107060952/http://b") + ".scorecardresearch.com/beacon.js";
#             el.parentNode.insertBefore(s, el);
#          })();
#   </script>
#   <noscript>
#    &lt;img src="/web/20130107060952im_/http://b.scorecardresearch.com/p?c1=2&amp;amp;c2=7705242&amp;amp;cv=2.0&amp;amp;cj=1" /&gt;
#   </noscript>
#   <div class="LiquidHeader" id="mappingHeader">
#    <a class="c21Logo" href="http://web.archive.org/web/20130107060952/http://www.century21.com/" onclick="Track.doEvent('Header', 'Logo');" title="CENTURY21 real estate, homes for sale and apartments for rent">
#    </a>
#    <span class="siteLinks">
#     <a href="http://web.archive.org/web/20130107060952/http://espanol.century21.com/" onclick="Track.doEvent('Header', 'Offsite', 'Espanol');" rel="nofollow" title="Español">
#      Español
#     </a>
#     |
#     <a href="http://web.archive.org/web/20130107060952/http://classic.century21.com/finehomes/" onclick="Track.doEvent('Header', 'Offsite', 'FHE');" title="Fine Homes">
#      Fine Homes
#     </a>
#     |
#     <a href="http://web.archive.org/web/20130107060952/http://classic.century21.com/commercial/" onclick="Track.doEvent('Header', 'Offsite', 'Commercial');" title="Commercial Real Estate">
#      Commercial Real Estate
#     </a>
#     |
#     <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/global" onclick="Track.doEvent('Header', 'Offsite', 'Global');" title="Global">
#      Global
#     </a>
#     |
#     <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/real-estate-blog" onclick="Track.doEvent('Header', 'Offsite', 'Blog');" target="_blank" title="C21 Blog">
#      C21 Blog
#     </a>
#    </span>
#    <ul class="headerNav">
#     <li>
#      <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property-search" id="NavigationFindHome" onclick="Track.doEvent('Header', 'Find A Home');" title="Find a Home">
#       Find A Home
#      </a>
#     </li>
#     <li>
#      <div class="NavigationSeparator">
#      </div>
#     </li>
#     <li>
#      <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/careerfranchise" id="NavigationJoinC21" onclick="Track.doEvent('Header', 'Join C21');" title="Join C21">
#       JoinC21
#      </a>
#     </li>
#     <li>
#      <div class="NavigationSeparator">
#      </div>
#     </li>
#     <li>
#      <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/buyingadvice" id="NavigationAdvice" onclick="Track.doEvent('Header', 'Advice');" title="Real Estate Advice">
#       Advice
#      </a>
#     </li>
#     <li>
#      <div class="NavigationSeparator">
#      </div>
#     </li>
#     <li>
#      <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/calculators" id="NavigationTools" onclick="Track.doEvent('Header', 'Tools');" title="Real Estate Calculators">
#       Tools
#      </a>
#     </li>
#    </ul>
#    <div class="lmDropdown">
#     <div id="dropdown">
#      <div id="dropdownSearchBox">
#       <input class="searchText" disabled="disabled" id="behindSearchText" name="behindFirstName" type="text"/>
#       <input class="searchText searchValue" id="searchText" name="firstname" type="text" value=""/>
#       <script>
#        var search = portalAjax.getCookie("LAST_SEARCH_STRING"); $(".searchText").val(search || "");
#       </script>
#       <a href="javascript:void(0);" id="searchReset" onclick="Track.doEvent('Free Text Search', 'Reset Search');">
#       </a>
#       <a href="javascript:void(0);" id="searchButton">
#       </a>
#      </div>
#      <div id="dropdownResults">
#       <div id="dropdownRepeat">
#       </div>
#       <div id="dropdownResultsTop">
#       </div>
#       <div id="dropdownResultsBottom">
#       </div>
#       <div id="dropdownSearchContent" style="position:relative;display:none;">
#        <div class="searchCriteria" id="searchCriteria">
#         <label class="freetextsearchPriceRangeLabel">
#          <b>
#           Price Range
#          </b>
#         </label>
#         <input id="priceFrom" maxlength="8" name="priceFrom" size="8" style="display: none;" type="text" value=""/>
#         <div class="c21textdropdown generated_648_input">
#          <div class="background">
#           Minimum
#          </div>
#          <input class="foreground" type="text"/>
#         </div>
#         <b class="toWord">
#          to
#         </b>
#         <input id="priceTo" maxlength="8" name="priceTo" size="8" style="display: none;" type="text" value=""/>
#         <div class="c21textdropdown generated_67_input">
#          <div class="background">
#           Maximum
#          </div>
#          <input class="foreground" type="text"/>
#         </div>
#         <select class="hide" id="priceOptions">
#          <option value="$10,000">
#           $10,000
#          </option>
#          <option value="$20,000">
#           $20,000
#          </option>
#          <option value="$30,000">
#           $30,000
#          </option>
#          <option value="$50,000">
#           $50,000
#          </option>
#          <option value="$75,000">
#           $75,000
#          </option>
#          <option value="$100,000">
#           $100,000
#          </option>
#          <option value="$125,000">
#           $125,000
#          </option>
#          <option value="$150,000">
#           $150,000
#          </option>
#          <option value="$175,000">
#           $175,000
#          </option>
#          <option value="$200,000">
#           $200,000
#          </option>
#          <option value="$225,000">
#           $225,000
#          </option>
#          <option value="$250,000">
#           $250,000
#          </option>
#          <option value="$300,000">
#           $300,000
#          </option>
#          <option value="$350,000">
#           $350,000
#          </option>
#          <option value="$400,000">
#           $400,000
#          </option>
#          <option value="$450,000">
#           $450,000
#          </option>
#          <option value="$500,000">
#           $500,000
#          </option>
#          <option value="$600,000">
#           $600,000
#          </option>
#          <option value="$700,000">
#           $700,000
#          </option>
#          <option value="$800,000">
#           $800,000
#          </option>
#          <option value="$1,000,000">
#           $1,000,000
#          </option>
#          <option value="$1,250,000">
#           $1,250,000
#          </option>
#          <option value="$1,500,000">
#           $1,500,000
#          </option>
#          <option value="$1,750,000">
#           $1,750,000
#          </option>
#          <option value="$2,000,000">
#           $2,000,000
#          </option>
#          <option value="$2,500,000">
#           $2,500,000
#          </option>
#          <option value="$3,000,000">
#           $3,000,000
#          </option>
#         </select>
#         <label class="freetextsearchPropLabel">
#          <b>
#           Beds
#          </b>
#         </label>
#         <select id="bedrooms" style="display: none;">
#          <option value="">
#           Any
#          </option>
#          <option value="1">
#           1+
#          </option>
#          <option value="2">
#           2+
#          </option>
#          <option value="3">
#           3+
#          </option>
#          <option value="4">
#           4+
#          </option>
#          <option value="5">
#           5+
#          </option>
#          <option value="6">
#           6+
#          </option>
#         </select>
#         <div class="selector smallSelector selectorCustomizations">
#          <span>
#           Any
#          </span>
#          <input class="generated_433_input" id="bedroomsFrom" name="bedroomsFrom" type="hidden" value=""/>
#          <input id="bedroomsTo" name="bedroomsTo" type="hidden" value=""/>
#         </div>
#         <label class="freetextsearchPropLabel">
#          <b>
#           Baths
#          </b>
#         </label>
#         <select id="bathrooms" style="display: none;">
#          <option value="">
#           Any
#          </option>
#          <option value="1">
#           1+
#          </option>
#          <option value="2">
#           2+
#          </option>
#          <option value="3">
#           3+
#          </option>
#          <option value="4">
#           4+
#          </option>
#          <option value="5">
#           5+
#          </option>
#          <option value="6">
#           6+
#          </option>
#         </select>
#         <div class="selector smallSelector selectorCustomizations">
#          <span>
#           Any
#          </span>
#          <input class="generated_374_input" id="bathroomsFrom" name="bathroomsFrom" type="hidden" value=""/>
#          <input id="bathroomsTo" name="bathroomsTo" type="hidden" value=""/>
#         </div>
#         <label class="freetextsearchPropLabel">
#          <b>
#           Sq. Ft.
#          </b>
#         </label>
#         <select id="structureSize" style="display: none;">
#          <option value="">
#           Any
#          </option>
#          <option value="250">
#           250+
#          </option>
#          <option value="500">
#           500+
#          </option>
#          <option value="1000">
#           1000+
#          </option>
#          <option value="2500">
#           2500+
#          </option>
#          <option value="5000">
#           5000+
#          </option>
#          <option value="10000">
#           10000+
#          </option>
#         </select>
#         <div class="selector smallSelector selectorSquareFeet">
#          <span>
#           Any
#          </span>
#          <input class="generated_706_input" id="structureSizeFrom" name="structureSizeFrom" type="hidden" value=""/>
#          <input id="structureSizeTo" name="structureSizeTo" type="hidden" value=""/>
#         </div>
#        </div>
#       </div>
#       <div id="dropdownContent">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="LiquidBody">
#    <div class="LiquidSubHeader">
#     <div id="BodyTopHeader">
#      <span class="breadCrumbs">
#       <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/">
#        CENTURY21 Home
#       </a>
#       ›
#       <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/real-estate-information/arizona-state/LSAZ">
#        Arizona
#       </a>
#       ›
#       <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/real-estate-information/rock-springs-az/LCAZROCKSPRINGS">
#        Rock Springs
#       </a>
#       ›
#       <span>
#        Homes for Sale
#       </span>
#      </span>
#      <script>
#       // DO NOT RUN TWICE
#    if (!window.g_pageLiquidLayout) {
#       // This must happen BEFORE dom ready
#       // (other scripts on this page depend on this variable existing);
#       window.g_pageLiquidLayout = new Century21.Maps.Page();
#    }
#      </script>
#     </div>
#     <div id="myC21Header">
#      <span class="subHeaderActions">
#       <span class="actionLabel">
#        My C21:
#       </span>
#       <span id="HeaderLoggedOff" style="display: inline;">
#        <a href="javascript:void(0);" onclick="Track.doEvent('Header', 'MyC21', 'Sign In'); myc21.loginForm.open();">
#         Sign In
#        </a>
#        |
#        <a href="javascript:void(0);" onclick="Track.doEvent('Header', 'MyC21', 'Create Account'); myc21.createAccountForm.open();">
#         Register
#        </a>
#        <span id="hideMyC21">
#         |
#         <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/myc21Overview.c21" onclick="Track.doEvent('Header', 'MyC21', 'View Favorites');">
#          My Favorites
#         </a>
#        </span>
#       </span>
#       <span id="HeaderLoggedIn" style="display: none;">
#        <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/myc21Overview.c21" id="myc21UsernameLabel" onclick="Track.doEvent('Header', 'MyC21', 'View Favorites');">
#         Hi,
#         <span id="myc21Username">
#         </span>
#        </a>
#        |
#        <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/myc21Overview.c21" onclick="Track.doEvent('Header', 'MyC21', 'View Favorites');">
#         My Favorites
#        </a>
#        |
#        <a href="javascript:void(0);" onclick="Track.doEvent('Header', 'MyC21', 'Sign Out'); myc21.logout();">
#         Sign Out
#        </a>
#       </span>
#      </span>
#     </div>
#    </div>
#    <div class="SchoolsModalDiv" id="SchoolsModalDiv" style="display: none">
#     <div class="schoolsToolTip" id="schoolsToolTip">
#      <div class="contentTip" style="top: 224px;">
#      </div>
#      <input id="selectedSchoolIds" type="hidden" value=""/>
#      <input id="schoolAttendanceRadius" type="hidden" value=""/>
#      <input id="schoolLocationOverride" type="hidden" value=""/>
#      <input id="schoolSearchInitialized" initialized="Y" type="hidden" value="N"/>
#      <input id="selectedSchoolFlags" type="hidden" value=""/>
#      <input id="currSelectedSchoolID" type="hidden" value=""/>
#      <div class="searchTabsSection" id="searchTabsSection">
#       <div class="modalShowTopRated">
#        <label for="modalTopRatedSchoolsRadio">
#         <div class="radio" id="uniform-modalTopRatedSchoolsRadio">
#          <span class="">
#           <input checked="checked" id="modalTopRatedSchoolsRadio" name="modalSchoolTypeRadio" style="opacity: 0;" type="radio"/>
#          </span>
#         </div>
#         Show Top Rated
#        </label>
#       </div>
#       <div class="modalYourSchools">
#        <label class="selected" for="modalShowYourSchoolsRadio">
#         <div class="radio" id="uniform-modalShowYourSchoolsRadio">
#          <span class="checked">
#           <input checked="checked" id="modalShowYourSchoolsRadio" name="modalSchoolTypeRadio" style="opacity: 0;" type="radio"/>
#          </span>
#         </div>
#         Show Your Schools
#        </label>
#       </div>
#       <div class="sortByDiv">
#        <label>
#         Sort by:
#        </label>
#        <div class="selector smallSelector" id="uniform-schoolSortTypes">
#         <span>
#          Rating
#         </span>
#         <select id="schoolSortTypes" style="opacity: 0;">
#          <option value="rating-desc">
#           Rating
#          </option>
#          <option value="gsrating-desc">
#           GreatSchools Rating
#          </option>
#          <option value="numstudents-asc">
#           Number of Students (lowest first)
#          </option>
#          <option value="numstudents-desc">
#           Number of Students (highest first)
#          </option>
#          <option value="stratio-asc">
#           Student Teacher Ratio
#          </option>
#          <option value="name-asc">
#           School Name A-Z
#          </option>
#          <option value="name-desc">
#           School Name Z-A
#          </option>
#          <option value="numreviews-asc">
#           Number of Reviews (lowest first)
#          </option>
#          <option value="numreviews-desc">
#           Number of Reviews (highest first)
#          </option>
#         </select>
#        </div>
#       </div>
#       <div class="modalCloseDiv">
#        <a href="javascript:void(0);" id="modalCloseLink" onclick="schoolSearch.closeWindow(); Track.doEvent('Schools', 'School Results Dialog', 'Close the school search results dialog');" title="Close">
#        </a>
#       </div>
#      </div>
#      <div class="clear">
#      </div>
#      <div class="searchCriteriaDiv">
#       <div class="searchCriteriaSection">
#        <div class="schoolNameDiv">
#         <input class="defaulttext" id="schoolName" name="schoolName" type="text" value=""/>
#        </div>
#        <div class="schoolGradesDiv">
#         <select id="lqschoolgrades" style="display: none;">
#          <option optionforany="true" selecteddisplay="Grades" value="">
#           Any
#          </option>
#          <option value="_GPS">
#           Preschool
#          </option>
#          <option value="_GEL">
#           Elementary
#          </option>
#          <option value="_GMI">
#           Middle
#          </option>
#          <option value="_GHI">
#           High School
#          </option>
#          <option value="-1|5">
#           Kindergarten - 5th
#          </option>
#          <option value="6|8">
#           6th - 8th
#          </option>
#          <option value="9|12">
#           9th - 12th
#          </option>
#          <option value="_ADU">
#           Adult
#          </option>
#          <option value="-2">
#           Pre-Kindergarten
#          </option>
#          <option value="-1">
#           Kindergarten
#          </option>
#          <option value="1">
#           1st
#          </option>
#          <option value="2">
#           2nd
#          </option>
#          <option value="3">
#           3rd
#          </option>
#          <option value="4">
#           4th
#          </option>
#          <option value="5">
#           5th
#          </option>
#          <option value="6">
#           6th
#          </option>
#          <option value="7">
#           7th
#          </option>
#          <option value="8">
#           8th
#          </option>
#          <option value="9">
#           9th
#          </option>
#          <option value="10">
#           10th
#          </option>
#          <option value="11">
#           11th
#          </option>
#          <option value="12">
#           12th
#          </option>
#         </select>
#         <div class="selector smallSelector lqselectorCustomizations">
#          <span>
#           Grades
#          </span>
#          <input class="generated_137_input" id="lqschoolgradesFrom" name="lqschoolgradesFrom" type="hidden" value=""/>
#          <input id="lqschoolgradesTo" name="lqschoolgradesTo" type="hidden" value=""/>
#         </div>
#         <input id="schoolgrade" type="hidden" value=""/>
#        </div>
#        <div class="schoolTypesDiv">
#         <div class="selector smallSelector" id="uniform-lqschooltypes">
#          <span>
#           School Type
#          </span>
#          <select id="lqschooltypes" style="opacity: 0;">
#           <option selecteddisplay="School Type" value="">
#            Any
#           </option>
#           <option value="public">
#            Public
#           </option>
#           <option value="private">
#            Private
#           </option>
#           <option value="state">
#            State
#           </option>
#           <option value="catholic">
#            Catholic
#           </option>
#          </select>
#         </div>
#        </div>
#        <div class="moreSearchOptionsSection">
#         <div class="moreStudentOptions">
#          <select id="lqstudents" style="display: none;">
#           <option optionforany="true" selecteddisplay="Total # of Students" value="">
#            Any
#           </option>
#           <option value="50">
#            Less than 50
#           </option>
#           <option value="100">
#            Less than 100
#           </option>
#           <option value="150">
#            Less than 150
#           </option>
#           <option value="200">
#            Less than 200
#           </option>
#           <option value="250">
#            Less than 250
#           </option>
#           <option value="300">
#            Less than 300
#           </option>
#           <option value="350">
#            Less than 350
#           </option>
#           <option value="400">
#            Less than 400
#           </option>
#           <option value="450">
#            Less than 450
#           </option>
#           <option value="500">
#            Less than 500
#           </option>
#           <option value="1000">
#            Less than 1000
#           </option>
#          </select>
#          <div class="selector smallSelector lqselectorCustomizations">
#           <span>
#            Total # of Students
#           </span>
#           <input class="generated_275_input" id="lqstudentsFrom" name="lqstudentsFrom" type="hidden" value=""/>
#           <input id="lqstudentsTo" name="lqstudentsTo" type="hidden" value=""/>
#          </div>
#          <select id="lqstudentratio" style="display: none;">
#           <option optionforany="true" selecteddisplay="Student/Teacher Ratio" value="">
#            Any
#           </option>
#           <option value="10">
#            Less than 10:1
#           </option>
#           <option value="20">
#            Less than 20:1
#           </option>
#           <option value="30">
#            Less than 30:1
#           </option>
#           <option value="40">
#            Less than 40:1
#           </option>
#           <option value="50">
#            Less than 50:1
#           </option>
#           <option value="100">
#            Less than 100:1
#           </option>
#          </select>
#          <div class="selector smallSelector lqselectorCustomizations">
#           <span>
#            Student/Teacher Ratio
#           </span>
#           <input class="generated_733_input" id="lqstudentratioFrom" name="lqstudentratioFrom" type="hidden" value=""/>
#           <input id="lqstudentratioTo" name="lqstudentratioTo" type="hidden" value=""/>
#          </div>
#         </div>
#         <div class="header">
#          Refined Search Options
#         </div>
#         <div class="searchOptionsColumn1">
#          <div class="flagoption">
#           <label for="schoolFlag_ADP">
#            <div class="checker" id="uniform-schoolFlag_ADP">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_ADP" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Advanced Placement
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_BAS">
#            <div class="checker" id="uniform-schoolFlag_BAS">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_BAS" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Before and After School Programs
#            </span>
#           </label>
#          </div>
#          <br/>
#          <div class="flagoption">
#           <label for="schoolFlag_BRS">
#            <div class="checker" id="uniform-schoolFlag_BRS">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_BRS" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Blue Ribbon School
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_CES">
#            <div class="checker" id="uniform-schoolFlag_CES">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_CES" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Coalition of Essential School
#            </span>
#           </label>
#          </div>
#          <br/>
#          <div class="flagoption">
#           <label for="schoolFlag_CHA">
#            <div class="checker" id="uniform-schoolFlag_CHA">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_CHA" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Charter School
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_GAT">
#            <div class="checker" id="uniform-schoolFlag_GAT">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_GAT" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Gifted and Talented
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_IBC">
#            <div class="checker" id="uniform-schoolFlag_IBC">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_IBC" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             International Baccalaureate
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_MAG">
#            <div class="checker" id="uniform-schoolFlag_MAG">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_MAG" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Magnet School
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_SIT">
#            <div class="checker" id="uniform-schoolFlag_SIT">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_SIT" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Site Based
#            </span>
#           </label>
#          </div>
#         </div>
#         <div class="searchOptionsColumn2">
#          <div class="flagoption">
#           <label for="schoolFlag_VOC">
#            <div class="checker" id="uniform-schoolFlag_VOC">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_VOC" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Vocational/Tech
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_ADU">
#            <div class="checker" id="uniform-schoolFlag_ADU">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_ADU" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Adult Education Classes
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_SPE">
#            <div class="checker" id="uniform-schoolFlag_SPE">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_SPE" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Special Education
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_APR">
#            <div class="checker" id="uniform-schoolFlag_APR">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_APR" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Alternative Programs
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_YRC">
#            <div class="checker" id="uniform-schoolFlag_YRC">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_YRC" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             Year Round Classes
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_ESL">
#            <div class="checker" id="uniform-schoolFlag_ESL">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_ESL" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             ESL
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_AYP">
#            <div class="checker" id="uniform-schoolFlag_AYP">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_AYP" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             AYP School
#            </span>
#           </label>
#          </div>
#          <div class="flagoption">
#           <label for="schoolFlag_NCL">
#            <div class="checker" id="uniform-schoolFlag_NCL">
#             <span>
#              <input class="schoolFlagCheckbox" id="schoolFlag_NCL" style="opacity: 0;" type="checkbox"/>
#             </span>
#            </div>
#            <span class="infoLabel">
#             NCLB School
#            </span>
#           </label>
#          </div>
#          <div class="submitOptionsButton">
#           <a href="javascript:void(0);" id="submitOptions" onclick="Track.doEvent('Schools', 'School Results Dialog', 'Filter by Refined Search Options'); schoolSearch.hideMoreSearchOptions();">
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <a class="moreSearchOptionsLink" href="javascript:void(0);">
#        More School Options
#       </a>
#      </div>
#      <div class="schoolSearchResults searchListSection" id="schoolSearchResults">
#      </div>
#      <div class="schoolDetailInformation" id="schoolDetailInformation">
#      </div>
#     </div>
#    </div>
#    <div class="SchoolModalRadiusSelect" id="SchoolModalRadiusSelect" style="display: none">
#     <div id="SchoolRadiusModalWindow">
#      <div id="modalBackdrop">
#      </div>
#      <div class="schoolRadiusBox" style="top: 240px; ">
#       <div id="modalContent">
#        <form id="schoolRadiusForm">
#         <div class="header">
#          Choose a radius
#         </div>
#         <br/>
#         <div class="info">
#          The school you chose doesn't have a designated attendance area.
#         </div>
#         <div class="info">
#          Please choose a radius to apply for schools without attendance zones.
#         </div>
#         <br/>
#         <div class="schoolRadiusButtons">
#          <div class="selector smallSelector" id="uniform-schoolRadiusSelector">
#           <span>
#            1 Mile
#           </span>
#           <select id="schoolRadiusSelector" style="opacity: 0;">
#            <option value="1">
#             1 Mile
#            </option>
#            <option value="2">
#             2 Miles
#            </option>
#            <option value="3">
#             3 Miles
#            </option>
#            <option value="4">
#             4 Miles
#            </option>
#            <option value="5">
#             5 Miles
#            </option>
#            <option value="10">
#             10 Miles
#            </option>
#            <option value="15">
#             15 Miles
#            </option>
#            <option value="20">
#             20 Miles
#            </option>
#            <option value="25">
#             25 Miles
#            </option>
#            <option value="30">
#             30 Miles
#            </option>
#            <option value="35">
#             35 Miles
#            </option>
#            <option value="40">
#             40 Miles
#            </option>
#            <option value="45">
#             45 Miles
#            </option>
#            <option value="50">
#             50 Miles
#            </option>
#           </select>
#          </div>
#          <a href="javascript:void(0);" id="radiusModalSubmitButton" onclick="schoolSearch.closeRadiusSelectDialog();">
#          </a>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#     <script>
#      $(document).ready(function() {
#       $("#schoolRadiusSelector").uniform();
#       $("#schoolRadiusSelector").change(function() {
#          Track.doEvent('Schools', 'Choose Attendance Radius Dialog', 'Change Radius', parseInt($("#schoolRadiusSelector option:selected").text()));
#       });
#    });
#     </script>
#    </div>
#    <div class="SchoolModalBoundary" id="SchoolModalBoundary" style="display: none">
#     <div id="SchoolBoundaryModalWindow">
#      <div id="modalBackdrop">
#      </div>
#      <div class="schoolBoundaryBox" style="top: 240px; ">
#       <div id="modalContent">
#        <form id="schoolBoundaryForm">
#         <div class="header">
#          Use School Boundaries?
#         </div>
#         <div class="infoLine1">
#          Homes exist outside of
#          <span class="schoolBoundaryLocation">
#           Rock Springs, AZ
#          </span>
#          that attend your chosen schools.
#         </div>
#         <div class="infoLine2">
#          Do you want to include these homes in your search results?
#         </div>
#         <div class="schoolBoundaryButtons">
#          <a href="javascript:void(0);" id="schoolBoundaryYesButton" onclick="schoolSearch.closeBoundarySelectDialog('Y');">
#          </a>
#          <a href="javascript:void(0);" id="schoolBoundaryNoButton" onclick="schoolSearch.closeBoundarySelectDialog('N');">
#          </a>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#     <script type="text/javascript">
#      $(document).ready(function() {
#       $(".schoolBoundaryLocation").text(" " + $("#searchText").val());
#    });
#     </script>
#    </div>
#    <div class="SchoolModalDeletion" id="SchoolModalDeletion" style="display: none">
#     <div id="SchoolDeletionModalWindow">
#      <div id="modalBackdrop">
#      </div>
#      <div class="schoolDeletionBox" style="top: 240px; ">
#       <div id="modalContent">
#        <form id="schoolDeletionForm">
#         <div class="header">
#          Delete Selected Schools?
#         </div>
#         <div class="infoLine1">
#          You have schools selected. Changing location will delete your selected schools.
#         </div>
#         <div class="infoLine2">
#          Do you want to proceed?
#         </div>
#         <div class="schoolDeletionButtons">
#          <a href="javascript:void(0);" id="schoolDeletionYesButton" onclick="schoolSearch.closeDeletionSelectDialog('Y');">
#          </a>
#          <a href="javascript:void(0);" id="schoolDeletionNoButton" onclick="schoolSearch.closeDeletionSelectDialog('N');">
#          </a>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#     <script type="text/javascript">
#      $(document).ready(function() {
#    });
#     </script>
#    </div>
#    <input id="discontinuedType" type="hidden" value=""/>
#    <div class="DiscontinuedTypeModal" id="DiscontinuedTypeModal" style="display: none">
#     <div id="DiscontinuedTypeModalWindow">
#      <div id="modalBackdrop">
#      </div>
#      <div class="discontinuedTypeBox" style="top: 240px; ">
#       <div id="modalContent">
#        <div class="modalCloseDiv">
# ...
#    <div class="dropdownHeader">
#     <div class="dropdownHeaderContainer">
#      <div class="background">
#       Maximum
#      </div>
#      <input class="foreground" maxlength="10" tabindex="101" type="text"/>
#     </div>
#    </div>
#    <div class="dropdownOptionViewport">
#     <div class="dropdownOptionContainer">
#      <div class="dropdownOption dropdownOptionOdd" value="$10,000">
#       $10,000
#      </div>
#      <div class="dropdownOption" value="$20,000">
#       $20,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$30,000">
#       $30,000
#      </div>
#      <div class="dropdownOption" value="$50,000">
#       $50,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$75,000">
#       $75,000
#      </div>
#      <div class="dropdownOption" value="$100,000">
#       $100,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$125,000">
#       $125,000
#      </div>
#      <div class="dropdownOption" value="$150,000">
#       $150,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$175,000">
#       $175,000
#      </div>
#      <div class="dropdownOption" value="$200,000">
#       $200,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$225,000">
#       $225,000
#      </div>
#      <div class="dropdownOption" value="$250,000">
#       $250,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$300,000">
#       $300,000
#      </div>
#      <div class="dropdownOption" value="$350,000">
#       $350,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$400,000">
#       $400,000
#      </div>
#      <div class="dropdownOption" value="$450,000">
#       $450,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$500,000">
#       $500,000
#      </div>
#      <div class="dropdownOption" value="$600,000">
#       $600,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$700,000">
#       $700,000
#      </div>
#      <div class="dropdownOption" value="$800,000">
#       $800,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$1,000,000">
#       $1,000,000
#      </div>
#      <div class="dropdownOption" value="$1,250,000">
#       $1,250,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$1,500,000">
#       $1,500,000
#      </div>
#      <div class="dropdownOption" value="$1,750,000">
#       $1,750,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$2,000,000">
#       $2,000,000
#      </div>
#      <div class="dropdownOption" value="$2,500,000">
#       $2,500,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$3,000,000">
#       $3,000,000
#      </div>
#     </div>
#    </div>
#   </div>
#   <iframe src="./LCWYROCKSPRINGS2_files/iframe.proxy.html" style="display: none">
#   </iframe>
#   <div class="dropdownBox lqdropdownCustomizations" id="generated_137" showing="false" style="top: -19998px; left: -19998px; display: block;">
#    <div class="dropdownHeader">
#     <div class="dropdownHeaderContainer">
#      <div class="dropdownTo">
#       to
#      </div>
#      <div class="dropdownHeaderStart">
#       <div class="background">
#        Min
#       </div>
#       <input class="foreground" maxlength="2" tabindex="402" type="text"/>
#      </div>
#      <div class="dropdownHeaderEnd">
#       <div class="background">
#        Max
#       </div>
#       <input class="foreground" maxlength="2" tabindex="403" type="text"/>
#      </div>
#     </div>
#    </div>
#    <div class="dropdownOptionViewport">
#     <div class="dropdownOptionContainer">
#      <div class="dropdownOption dropdownOptionOdd dropdownOptionSelected" selecteddisplay="Grades" value="">
#       Any
#      </div>
#      <div class="dropdownOption" value="_GPS">
#       Preschool
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="_GEL">
#       Elementary
#      </div>
#      <div class="dropdownOption" value="_GMI">
#       Middle
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="_GHI">
#       High School
#      </div>
#      <div class="dropdownOption" value="-1|5">
#       Kindergarten - 5th
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="6|8">
#       6th - 8th
#      </div>
#      <div class="dropdownOption" value="9|12">
#       9th - 12th
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="_ADU">
#       Adult
#      </div>
#      <div class="dropdownOption" value="-2">
#       Pre-Kindergarten
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="-1">
#       Kindergarten
#      </div>
#      <div class="dropdownOption" value="1">
#       1st
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="2">
#       2nd
#      </div>
#      <div class="dropdownOption" value="3">
#       3rd
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="4">
#       4th
#      </div>
#      <div class="dropdownOption" value="5">
#       5th
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="6">
#       6th
#      </div>
#      <div class="dropdownOption" value="7">
#       7th
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="8">
#       8th
#      </div>
#      <div class="dropdownOption" value="9">
#       9th
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="10">
#       10th
#      </div>
#      <div class="dropdownOption" value="11">
#       11th
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="12">
#       12th
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="dropdownBox lqdropdownCustomizations" id="generated_275" showing="false" style="top: -19998px; left: -19998px; display: block;">
#    <div class="dropdownHeader">
#     <div class="dropdownHeaderContainer">
#      <div class="dropdownTo">
#       to
#      </div>
#      <div class="dropdownHeaderStart">
#       <div class="background">
#        Min
#       </div>
#       <input class="foreground" maxlength="4" tabindex="404" type="text"/>
#      </div>
#      <div class="dropdownHeaderEnd">
#       <div class="background">
#        Max
#       </div>
#       <input class="foreground" maxlength="4" tabindex="405" type="text"/>
#      </div>
#     </div>
#    </div>
#    <div class="dropdownOptionViewport">
#     <div class="dropdownOptionContainer">
#      <div class="dropdownOption dropdownOptionOdd dropdownOptionSelected" selecteddisplay="Total # of Students" value="">
#       Any
#      </div>
#      <div class="dropdownOption" value="50">
#       Less than 50
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="100">
#       Less than 100
#      </div>
#      <div class="dropdownOption" value="150">
#       Less than 150
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="200">
#       Less than 200
#      </div>
#      <div class="dropdownOption" value="250">
#       Less than 250
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="300">
#       Less than 300
#      </div>
#      <div class="dropdownOption" value="350">
#       Less than 350
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="400">
#       Less than 400
#      </div>
#      <div class="dropdownOption" value="450">
#       Less than 450
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="500">
#       Less than 500
#      </div>
#      <div class="dropdownOption" value="1000">
#       Less than 1000
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="dropdownBox lqdropdownCustomizations" id="generated_733" showing="false" style="top: -19998px; left: -19998px; display: block;">
#    <div class="dropdownHeader">
#     <div class="dropdownHeaderContainer">
#      <div class="dropdownTo">
#       to
#      </div>
#      <div class="dropdownHeaderStart">
#       <div class="background">
#        Min
#       </div>
#       <input class="foreground" maxlength="3" tabindex="406" type="text"/>
#      </div>
#      <div class="dropdownHeaderEnd">
#       <div class="background">
#        Max
#       </div>
#       <input class="foreground" maxlength="3" tabindex="407" type="text"/>
#      </div>
#     </div>
#    </div>
#    <div class="dropdownOptionViewport">
#     <div class="dropdownOptionContainer">
#      <div class="dropdownOption dropdownOptionOdd dropdownOptionSelected" selecteddisplay="Student/Teacher Ratio" value="">
#       Any
#      </div>
#      <div class="dropdownOption" value="10">
#       Less than 10:1
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="20">
#       Less than 20:1
#      </div>
#      <div class="dropdownOption" value="30">
#       Less than 30:1
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="40">
#       Less than 40:1
#      </div>
#      <div class="dropdownOption" value="50">
#       Less than 50:1
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="100">
#       Less than 100:1
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="dropdownBox lqdropdownCustomizations" id="generated_111" showing="false" style="top: -19998px; left: -19998px; display: block;">
#    <div class="dropdownHeader">
#     <div class="dropdownHeaderContainer">
#      <div class="dropdownTo">
#       to
#      </div>
#      <div class="dropdownHeaderStart">
#       <div class="background">
#        Min
#       </div>
#       <input class="foreground" maxlength="2" tabindex="402" type="text"/>
#      </div>
#      <div class="dropdownHeaderEnd">
#       <div class="background">
#        Max
#       </div>
#       <input class="foreground" maxlength="2" tabindex="403" type="text"/>
#      </div>
#     </div>
#    </div>
#    <div class="dropdownOptionViewport">
#     <div class="dropdownOptionContainer">
#      <div class="dropdownOption dropdownOptionOdd dropdownOptionSelected" value="">
#       Any
#      </div>
#      <div class="dropdownOption" value="1">
#       1+
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="2">
#       2+
#      </div>
#      <div class="dropdownOption" value="3">
#       3+
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="4">
#       4+
#      </div>
#      <div class="dropdownOption" value="5">
#       5+
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="6">
#       6+
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="dropdownBox lqdropdownCustomizations" id="generated_636" showing="false" style="top: -19998px; left: -19998px; display: block;">
#    <div class="dropdownHeader">
#     <div class="dropdownHeaderContainer">
#      <div class="dropdownTo">
#       to
#      </div>
#      <div class="dropdownHeaderStart">
#       <div class="background">
#        Min
#       </div>
#       <input class="foreground" maxlength="2" tabindex="404" type="text"/>
#      </div>
#      <div class="dropdownHeaderEnd">
#       <div class="background">
#        Max
#       </div>
#       <input class="foreground" maxlength="2" tabindex="405" type="text"/>
#      </div>
#     </div>
#    </div>
#    <div class="dropdownOptionViewport">
#     <div class="dropdownOptionContainer">
#      <div class="dropdownOption dropdownOptionOdd dropdownOptionSelected" value="">
#       Any
#      </div>
#      <div class="dropdownOption" value="1">
#       1+
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="2">
#       2+
#      </div>
#      <div class="dropdownOption" value="3">
#       3+
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="4">
#       4+
#      </div>
#      <div class="dropdownOption" value="5">
#       5+
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="6">
#       6+
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="dropdownBox lqdropdownCustomizations" id="generated_9" showing="false" style="top: -19998px; left: -19998px; display: block;">
#    <div class="dropdownHeader">
#     <div class="dropdownHeaderContainer">
#      <div class="dropdownTo">
#       to
#      </div>
#      <div class="dropdownHeaderStart">
#       <div class="background">
#        Min
#       </div>
#       <input class="foreground" maxlength="7" tabindex="406" type="text"/>
#      </div>
#      <div class="dropdownHeaderEnd">
#       <div class="background">
#        Max
#       </div>
#       <input class="foreground" maxlength="7" tabindex="407" type="text"/>
#      </div>
#     </div>
#    </div>
#    <div class="dropdownOptionViewport">
#     <div class="dropdownOptionContainer">
#      <div class="dropdownOption dropdownOptionOdd dropdownOptionSelected" value="">
#       Any
#      </div>
#      <div class="dropdownOption" value="250">
#       250+
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="500">
#       500+
#      </div>
#      <div class="dropdownOption" value="1000">
#       1000+
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="2500">
#       2500+
#      </div>
#      <div class="dropdownOption" value="5000">
#       5000+
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="10000">
#       10000+
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="dropdownBox lqdropdownCustomizations" id="generated_390" showing="false" style="top: -19998px; left: -19998px; display: block;">
#    <div class="dropdownHeader">
#     <div class="dropdownHeaderContainer">
#      <div class="dropdownTo">
#       to
#      </div>
#      <div class="dropdownHeaderStart">
#       <div class="background">
#        Min
#       </div>
#       <input class="foreground" maxlength="7" tabindex="400" type="text"/>
#      </div>
#      <div class="dropdownHeaderEnd">
#       <div class="background">
#        Max
#       </div>
#       <input class="foreground" maxlength="7" tabindex="401" type="text"/>
#      </div>
#     </div>
#    </div>
#    <div class="dropdownOptionViewport">
#     <div class="dropdownOptionContainer">
#      <div class="dropdownOption dropdownOptionOdd dropdownOptionSelected" value="">
#       Any
#      </div>
#      <div class="dropdownOption" value="$10,000">
#       $10,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$20,000">
#       $20,000
#      </div>
#      <div class="dropdownOption" value="$30,000">
#       $30,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$50,000">
#       $50,000
#      </div>
#      <div class="dropdownOption" value="$75,000">
#       $75,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$100,000">
#       $100,000
#      </div>
#      <div class="dropdownOption" value="$125,000">
#       $125,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$150,000">
#       $150,000
#      </div>
#      <div class="dropdownOption" value="$175,000">
#       $175,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$200,000">
#       $200,000
#      </div>
#      <div class="dropdownOption" value="$225,000">
#       $225,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$250,000">
#       $250,000
#      </div>
#      <div class="dropdownOption" value="$300,000">
#       $300,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$350,000">
#       $350,000
#      </div>
#      <div class="dropdownOption" value="$400,000">
#       $400,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$450,000">
#       $450,000
#      </div>
#      <div class="dropdownOption" value="$500,000">
#       $500,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$600,000">
#       $600,000
#      </div>
#      <div class="dropdownOption" value="$700,000">
#       $700,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$800,000">
#       $800,000
#      </div>
#      <div class="dropdownOption" value="$1,000,000">
#       $1,000,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$1,250,000">
#       $1,250,000
#      </div>
#      <div class="dropdownOption" value="$1,500,000">
#       $1,500,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$1,750,000">
#       $1,750,000
#      </div>
#      <div class="dropdownOption" value="$2,000,000">
#       $2,000,000
#      </div>
#      <div class="dropdownOption dropdownOptionOdd" value="$2,500,000">
#       $2,500,000
#      </div>
#      <div class="dropdownOption" value="$3,000,000">
#       $3,000,000
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
#  <div>
#  </div>
# </html>

# %%
# all
# len(all)
# all[0]

# %%
# all[0].find_all("h4", {"class": "propPrice"})
# all[0].find("h4", {"class": "propPrice"}).
# all[0].find("h4", {"class": "propPrice"}).text.replace("\n","").replace(" ", "")

# %%
l = []

base_url = "https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="

for page in range(0,int(page_nr)*10,10):
#     print(base_url + str(page) + ".html")
    r = requests.get(base_url + str(page) + ".html")
    c = r.content
    soup = BeautifulSoup(c, "html.parser")
    all = soup.find_all("div", {"class": "propertyRow"})

    for item in all:
        d = {}
        d["Address"] = item.find_all("span", {"class", "propAddressCollapse"})[0].text
        try:
            d["Locality"] = item.find_all("span", {"class", "propAddressCollapse"})[1].text
        except:
            d["Locality"] = None
        d["Price"] = item.find("h4", {"class": "propPrice"}).text.replace("\n","").replace(" ", "")


        try:
            d["Beds"] = item.find("span", {"class","infoBed"}).find("b").text
        except:
            d["Beds"] = None

        try: 
            d["Area"] = item.find("span", {"class","infoSqFt"}).find("b").text
        except:
            d["Area"] = None

        try:
            d["Full Baths"] = item.find("span", {"class","infoValueFullBath"}).find("b").text
        except:
            d["Full Baths"] = None

        try:
            d["Half Baths"] = item.find("span", {"class","infoValueHalflBath"}).find("b").text
        except:
            d["Half Baths"] = None

        for column_group in item.find_all("div", {"class": "columnGroup"}):
    #         print(column_group)

            for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}), column_group.find_all("span",{"class":"featureName"})):
    #             print(feature_group.text, feature_name.text)
                if "Lot Size" in feature_group.text:
                    d["Lot Size"]= feature_name.text

    #     print(" ")
        l.append(d)

# %%
# l

# %%
len(l)
# Out:
# 37

# %%
import pandas
df = pandas.DataFrame(l)

# %%
df
# Out:
#                           Address                     Locality       Price  \
# 0                       0 Gateway       Rock Springs, WY 82901    $725,000
# 1           1003 Winchester Blvd.       Rock Springs, WY 82901    $452,900
# 2                   600 Talladega       Rock Springs, WY 82901    $396,900
# 3              3239 Spearhead Way       Rock Springs, WY 82901    $389,900
# 4              522 Emerald Street       Rock Springs, WY 82901    $254,000
# 5            1302 Veteran's Drive       Rock Springs, WY 82901    $252,900
# 6                1021 Cypress Cir       Rock Springs, WY 82901    $210,000
# 7                  913 Madison Dr       Rock Springs, WY 82901    $209,000
# 8               1344 Teton Street       Rock Springs, WY 82901    $199,900
# 9                  4 Minnies Lane       Rock Springs, WY 82901    $196,900
# 10                  9339 Sd 26900        Rocksprings, TX 78880  $1,700,000
# 11               RR674P13 Hwy 377        Rocksprings, TX 78880  $1,100,000
# 12                       0 Hwy 41        Rocksprings, TX 78880  $1,080,000
# 13                  9339 Sd 26900        Rocksprings, TX 78880    $908,350
# 14                  CR450 Hwy 377        Rocksprings, TX 78880    $905,000
# 15                  Cr 240 Cr 240        Rocksprings, TX 78880    $695,000
# 16                  RR674 Hwy 377        Rocksprings, TX 78880    $605,000
# 17                 9770a Sd 26900        Rocksprings, TX 78880    $559,805
# 18                  Lot17 CR 2630        Rocksprings, TX 78880    $504,000
# 19                 Tr12,16 CR 520        Rocksprings, TX 78880    $410,000
# 20   32575 S Shadow Mountain Road  Black Canyon City, AZ 85324    $299,900
# 21        32750 S Shangrila Drive  Black Canyon City, AZ 85324    $167,500
# 22      0000 Black Canyon Highway  Black Canyon City, AZ 85324    $150,000
# 23           34775 S CHOLLA Drive  Black Canyon City, AZ 85324    $129,500
# 24      33403 S. HA-WA-SI TERRACE  BLACK CANYON CITY, AZ 85324    $129,000
# 25          34263 S Bertha Street  Black Canyon City, AZ 85324     $80,000
# 26            33160 S Canyon Road  Black Canyon City, AZ 85324     $77,900
# 27        19421 E Todd Evans Road  Black Canyon City, AZ 85324     $70,500
# 28             18688 E AGUA Vista  Black Canyon City, AZ 85324     $70,000
# 29  50600 N Old Black Canyon Road  Black Canyon City, AZ 85324     $67,500
# 30      20101 E SQUAW VALLEY Road  Black Canyon City, AZ 85324     $54,900
# 31            33259 S Canyon Road  Black Canyon City, AZ 85324     $45,600
# 32          34558 S ROADRUNNER RD  Black Canyon City, AZ 85324     $40,000
# 33       19260 E Scenic Loop Road  Black Canyon City, AZ 85324     $30,000
# 34           19000 E MAREN Avenue  Black Canyon City, AZ 85324     $29,000
# 35          19350 E SAGUARO Drive  Black Canyon City, AZ 85324     $28,995
# 36         20650 E Amethyst Place  Black Canyon City, AZ 85324     $15,000
#
#     Beds   Area Full Baths Half Baths          Lot Size
# 0   None   None       None       None               NaN
# 1      4   None          4       None        0.21 Acres
# 2      5  3,154          3       None               NaN
# 3      4  3,076          3       None  Under 1/2 Acre,
# 4      3  1,172          3       None  Under 1/2 Acre,
# 5      4  1,932          2       None        0.27 Acres
# 6      4  1,676          3       None  Under 1/2 Acre,
# 7      3  1,344          2       None  Under 1/2 Acre,
# 8      3  1,920          2       None  Under 1/2 Acre,
# 9      3  1,664          2       None        2.02 Acres
# 10  None  2,560       None       None               NaN
# 11  None  2,000       None       None               NaN
# 12  None   None       None       None               NaN
# 13  None  2,560       None       None               NaN
# 14  None   None       None       None               NaN
# 15  None  1,398       None       None               NaN
# 16  None  1,738       None       None               NaN
# 17  None  1,080       None       None               NaN
# 18  None   None       None       None               NaN
# 19  None   None       None       None               NaN
# 20     3  2,318          2       None               NaN
# 21     3  2,120          2       None               NaN
# 22  None   None       None       None           5 Acres
# 23     3  1,220          2       None               NaN
# 24     4  2,000          2       None               NaN
# 25     5  2,260          2       None               NaN
# 26     3  1,248          2       None               NaN
# 27     3  1,404          2       None               NaN
# 28  None   None       None       None         0.7 Acres
# 29  None   None       None       None           3 Acres
# 30  None   None       None       None               NaN
# 31     3  1,056          1       None               NaN
# 32     2    784          1       None    Under 1/2 Acre
# 33  None   None       None       None        2.35 Acres
# 34  None   None       None       None        2.05 Acres
# 35  None   None       None       None        0.73 Acres
# 36  None   None       None       None        0.31 Acres

# %%
df.to_csv("Output.csv")

# %%
# base_url = "https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="

# for page in range(0,30,10):
# #     print(base_url + str(page) + ".html")
#     r = requests.get(base_url + str(page) + ".html")
#     c = r.content
#     soup = BeautifulSoup(c, "html.parser")
#     all = soup.find_all("div", {"class": "propertyRow"})
#     print(all)
